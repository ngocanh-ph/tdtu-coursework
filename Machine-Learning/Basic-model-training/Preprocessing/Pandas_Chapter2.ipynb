# %% [markdown]
# # CÁC PHƯƠNG THỨC HÀM VÀ HÀM THƯỜNG DÙNG TRONG PANDAS

# %% [markdown]
# ### Tái định danh một mẫu (Reindexing)
# Reindexing là thao tác tạo ra một đối tượng Pandas mới với chỉ mục mới, đồng thời sắp xếp lại dữ liệu theo chỉ mục đó.

# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
obj = Series([4.5, 7.2, -5.3, 3.6], index=['d','b','a','c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64
